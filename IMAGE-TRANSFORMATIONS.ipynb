# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the input image
input_image = cv2.imread("frnd dogs.jpg")

# %%
# Convert from BGR to RGB so we can plot using matplotlib
input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)

# %%
# Disable x & y axis
plt.axis('off')

# Show the image
plt.imshow(input_image)
plt.title("Original Image")
plt.show()

# %% [markdown]
# Image Translation

# %%
rows, cols, _ = image.shape
M_translate = np.float32([[1, 0, 50], [0, 1, 200]])  # Translate by (50, 100) pixels
translated_image = cv2.warpAffine(image_rgb, M_translate, (cols, rows))
plt.imshow(translated_image)
plt.title("Translated Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(920.5), np.float64(1279.5), np.float64(-0.5))

# %% [markdown]
# Image Scaling

# %%
scaled_image = cv2.resize(image_rgb, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR)  # Scale by 1.5x
plt.imshow(scaled_image)
plt.title("Scaled Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1381.5), np.float64(1919.5), np.float64(-0.5))

# %% [markdown]
# Image shearing

# %%
M_shear = np.float32([[1, 0.5, 0], [0.5, 1, 0]])  # Shear with factor 0.5
sheared_image = cv2.warpAffine(image_rgb, M_shear, (int(cols * 1.5), int(rows * 1.5)))
plt.imshow(sheared_image)
plt.title("Sheared Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1380.5), np.float64(1919.5), np.float64(-0.5))

# %% [markdown]
# Image Reflection

# %%
reflected_image = cv2.flip(image_rgb, 1)  # Horizontal reflection (flip along y-axis)
plt.imshow(reflected_image)
plt.title("Reflected Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(920.5), np.float64(1279.5), np.float64(-0.5))

# %% [markdown]
# Image Rotation

# %%
M_rotate = cv2.getRotationMatrix2D((cols / 2, rows / 2), 45, 1)  # Rotate by 45 degrees
rotated_image = cv2.warpAffine(image_rgb, M_rotate, (cols, rows))
plt.imshow(rotated_image)
plt.title("Rotated Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(920.5), np.float64(1279.5), np.float64(-0.5))

# %% [markdown]
# Image Cropping

# %%
cropped_image = image_rgb[50:300, 100:400]  # Crop a portion of the image
plt.figure(figsize=(4, 4))
plt.imshow(cropped_image)
plt.title("Cropped Image")
plt.axis('off')
plt.show()
